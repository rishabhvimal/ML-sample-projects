# %%
import pandas as pd

# %%
df = pd.read_csv("survey_results_public.csv")
df_schema = pd.read_csv("survey_results_schema.csv")

# %%
pd.set_option('display.max_columns', 85)
pd.set_option('display.max_rows', 85)

# %%
df_schema.set_index('Column', inplace=True)

# %%
df_schema.sort_index(inplace=True)

# %%
df_schema
# Out:
#                                                              QuestionText
# Column
# Age                     What is your age (in years)? If you prefer not...
# Age1stCode              At what age did you write your first line of c...
# BetterLife              Do you think people born today will have a bet...
# BlockchainIs            Blockchain / cryptocurrency technology is prim...
# BlockchainOrg           How is your organization thinking about or imp...
# CareerSat               Overall, how satisfied are you with your caree...
# CodeRev                          Do you review code as part of your work?
# CodeRevHrs              On average, how many hours per week do you spe...
# CompFreq                 Is that compensation weekly, monthly, or yearly?
# CompTotal               What is your current total compensation (salar...
# Containers              How do you use containers (Docker, Open Contai...
# ConvertedComp           Salary converted to annual USD salaries using ...
# ...

# %%
df.head()
# Out:
#    Respondent                                         MainBranch Hobbyist  \
# 0           1             I am a student who is learning to code      Yes
# 1           2             I am a student who is learning to code       No
# 2           3  I am not primarily a developer, but I write co...      Yes
# 3           4                     I am a developer by profession       No
# 4           5                     I am a developer by profession      Yes
#
#                   OpenSourcer  \
# 0                       Never
# 1     Less than once per year
# 2                       Never
# 3                       Never
# 4  Once a month or more often
#
#                                           OpenSource  \
# 0  The quality of OSS and closed source software ...
# 1  The quality of OSS and closed source software ...
# 2  The quality of OSS and closed source software ...
# 3  The quality of OSS and closed source software ...
# 4  OSS is, on average, of HIGHER quality than pro...
#
# ...

# %%
df.shape
# Out:
# (88883, 85)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 88883 entries, 0 to 88882
# Data columns (total 85 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Respondent              88883 non-null  int64
#  1   MainBranch              88331 non-null  object
#  2   Hobbyist                88883 non-null  object
#  3   OpenSourcer             88883 non-null  object
#  4   OpenSource              86842 non-null  object
#  5   Employment              87181 non-null  object
#  6   Country                 88751 non-null  object
#  7   Student                 87014 non-null  object
#  8   EdLevel                 86390 non-null  object
#  9   UndergradMajor          75614 non-null  object
#  10  EduOther                84260 non-null  object
#  11  OrgSize                 71791 non-null  object
#  12  DevType                 81335 non-null  object
#  13  YearsCode               87938 non-null  object
# ...

# %%
df.isna().sum()
# Out:
# Respondent                    0
# MainBranch                  552
# Hobbyist                      0
# OpenSourcer                   0
# OpenSource                 2041
# Employment                 1702
# Country                     132
# Student                    1869
# EdLevel                    2493
# UndergradMajor            13269
# EduOther                   4623
# OrgSize                   17092
# DevType                    7548
# YearsCode                   945
# Age1stCode                 1249
# YearsCodePro              14552
# CareerSat                 16036
# JobSat                    17895
# MgrIdiot                  27724
# MgrMoney                  27726
# MgrWant                   27651
# JobSeek                    8328
# LastHireDate               9029
# LastInt                   21728
# FizzBuzz                  17539
# JobFactors                 9512
# ResumeUpdate              11006
# CurrencySymbol            17491
# CurrencyDesc              17491
# ...

# %%
df[['Respondent', 'Age']]
# Out:
#        Respondent   Age
# 0               1  14.0
# 1               2  19.0
# 2               3  28.0
# 3               4  22.0
# 4               5  30.0
# ...           ...   ...
# 88878       88377   NaN
# 88879       88601   NaN
# 88880       88802   NaN
# 88881       88816   NaN
# 88882       88863  18.0
#
# [88883 rows x 2 columns]

# %%
df.iloc[0:5,:4]
# Out:
#    Respondent                                         MainBranch Hobbyist  \
# 0           1             I am a student who is learning to code      Yes
# 1           2             I am a student who is learning to code       No
# 2           3  I am not primarily a developer, but I write co...      Yes
# 3           4                     I am a developer by profession       No
# 4           5                     I am a developer by profession      Yes
#
#                   OpenSourcer
# 0                       Never
# 1     Less than once per year
# 2                       Never
# 3                       Never
# 4  Once a month or more often

# %%
df['Gender'].value_counts()
# Out:
# Man                                                            77919
# Woman                                                           6344
# Non-binary, genderqueer, or gender non-conforming                597
# Man;Non-binary, genderqueer, or gender non-conforming            181
# Woman;Non-binary, genderqueer, or gender non-conforming          163
# Woman;Man                                                        132
# Woman;Man;Non-binary, genderqueer, or gender non-conforming       70
# Name: Gender, dtype: int64

# %%
df.index
# Out:
# RangeIndex(start=0, stop=88883, step=1)

# %%
df.set_index('Respondent', inplace=True)

# %%
df.loc[1:5,'MainBranch']
# Out:
# Respondent
# 1               I am a student who is learning to code
# 2               I am a student who is learning to code
# 3    I am not primarily a developer, but I write co...
# 4                       I am a developer by profession
# 5                       I am a developer by profession
# Name: MainBranch, dtype: object

# %%
df.reset_index(inplace=True)

# %%
df.sort_index()
# Out:
#        Respondent                                         MainBranch Hobbyist  \
# 0               1             I am a student who is learning to code      Yes
# 1               2             I am a student who is learning to code       No
# 2               3  I am not primarily a developer, but I write co...      Yes
# 3               4                     I am a developer by profession       No
# 4               5                     I am a developer by profession      Yes
# ...           ...                                                ...      ...
# 88878       88377                                                NaN      Yes
# 88879       88601                                                NaN       No
# 88880       88802                                                NaN       No
# 88881       88816                                                NaN       No
# 88882       88863                                                NaN      Yes
#
# ...

# %%
filt = (df['Hobbyist']== 'Yes')

# %%
df[filt]
# Out:
#        Respondent                                         MainBranch Hobbyist  \
# 0               1             I am a student who is learning to code      Yes
# 2               3  I am not primarily a developer, but I write co...      Yes
# 4               5                     I am a developer by profession      Yes
# 5               6  I am not primarily a developer, but I write co...      Yes
# 7               8                        I code primarily as a hobby      Yes
# ...           ...                                                ...      ...
# 88872       87739                                                NaN      Yes
# 88875       88182                                                NaN      Yes
# 88877       88282                                                NaN      Yes
# 88878       88377                                                NaN      Yes
# 88882       88863                                                NaN      Yes
#
# ...

# %%
df.loc[filt,'OpenSource']
# Out:
# 0        The quality of OSS and closed source software ...
# 2        The quality of OSS and closed source software ...
# 4        OSS is, on average, of HIGHER quality than pro...
# 5        The quality of OSS and closed source software ...
# 7        OSS is, on average, of HIGHER quality than pro...
#                                ...
# 88872    OSS is, on average, of HIGHER quality than pro...
# 88875    OSS is, on average, of HIGHER quality than pro...
# 88877    The quality of OSS and closed source software ...
# 88878    The quality of OSS and closed source software ...
# 88882    OSS is, on average, of HIGHER quality than pro...
# Name: OpenSource, Length: 71257, dtype: object

# %%
df.loc[~filt,'OpenSource'] # It will negate the filter and give all values except that filter
# Out:
# 1        The quality of OSS and closed source software ...
# 3        The quality of OSS and closed source software ...
# 6        The quality of OSS and closed source software ...
# 11       OSS is, on average, of HIGHER quality than pro...
# 19       OSS is, on average, of HIGHER quality than pro...
#                                ...
# 88874    OSS is, on average, of HIGHER quality than pro...
# 88876    OSS is, on average, of HIGHER quality than pro...
# 88879    The quality of OSS and closed source software ...
# 88880                                                  NaN
# 88881    OSS is, on average, of HIGHER quality than pro...
# Name: OpenSource, Length: 17626, dtype: object

# %%
df[df['ConvertedComp'] > 70000][['Country','LanguageWorkedWith','ConvertedComp']]
# Out:
#               Country                                 LanguageWorkedWith  \
# 5              Canada                                         Java;R;SQL
# 8         New Zealand  Bash/Shell/PowerShell;C#;HTML/CSS;JavaScript;P...
# 12      United States  Bash/Shell/PowerShell;HTML/CSS;JavaScript;PHP;...
# 15     United Kingdom  Bash/Shell/PowerShell;C#;HTML/CSS;JavaScript;T...
# 21      United States  Bash/Shell/PowerShell;C++;HTML/CSS;JavaScript;...
# ...               ...                                                ...
# 88323   United States  Bash/Shell/PowerShell;C#;HTML/CSS;Java;Python;...
# 88324   United States  Bash/Shell/PowerShell;C;Clojure;HTML/CSS;Java;...
# 88325   United States               HTML/CSS;JavaScript;Scala;TypeScript
# 88326         Finland                   Bash/Shell/PowerShell;C++;Python
# 88329     Netherlands             C#;HTML/CSS;Java;JavaScript;PHP;Python
#
#        ConvertedComp
# 5           366420.0
# 8            95179.0
# 12           90000.0
# ...

# %%
filt = df['LanguageWorkedWith'].str.contains('Python', na = False)

# %%
df[filt][['Country','LanguageWorkedWith','ConvertedComp']]
# Out:
#                       Country  \
# 0              United Kingdom
# 1      Bosnia and Herzegovina
# 3               United States
# 4                     Ukraine
# 7                       India
# ...                       ...
# 88854          United Kingdom
# 88860                  Brazil
# 88865             Switzerland
# 88872          Czech Republic
# 88876                   Spain
#
#                                       LanguageWorkedWith  ConvertedComp
# 0                        HTML/CSS;Java;JavaScript;Python            NaN
# 1                                    C++;HTML/CSS;Python            NaN
# 3                                    C;C++;C#;Python;SQL        61000.0
# 4            C++;HTML/CSS;Java;JavaScript;Python;SQL;VBA            NaN
# 7      Bash/Shell/PowerShell;C;C++;HTML/CSS;Java;Java...            NaN
# ...                                                  ...            ...
# 88854  Bash/Shell/PowerShell;C;C++;HTML/CSS;Java;Java...            NaN
# ...

# %%
df[filt][['Country','LanguageWorkedWith','ConvertedComp']]
# Out:
#                       Country  \
# 0              United Kingdom
# 1      Bosnia and Herzegovina
# 3               United States
# 4                     Ukraine
# 7                       India
# ...                       ...
# 88854          United Kingdom
# 88860                  Brazil
# 88865             Switzerland
# 88872          Czech Republic
# 88876                   Spain
#
#                                       LanguageWorkedWith  ConvertedComp
# 0                        HTML/CSS;Java;JavaScript;Python            NaN
# 1                                    C++;HTML/CSS;Python            NaN
# 3                                    C;C++;C#;Python;SQL        61000.0
# 4            C++;HTML/CSS;Java;JavaScript;Python;SQL;VBA            NaN
# 7      Bash/Shell/PowerShell;C;C++;HTML/CSS;Java;Java...            NaN
# ...                                                  ...            ...
# 88854  Bash/Shell/PowerShell;C;C++;HTML/CSS;Java;Java...            NaN
# ...

# %%
df.columns = [x.lower() for x in df.columns]

# %%
df.head()
# Out:
#    respondent                                         mainbranch hobbyist  \
# 0           1             I am a student who is learning to code      Yes
# 1           2             I am a student who is learning to code       No
# 2           3  I am not primarily a developer, but I write co...      Yes
# 3           4                     I am a developer by profession       No
# 4           5                     I am a developer by profession      Yes
#
#                   opensourcer  \
# 0                       Never
# 1     Less than once per year
# 2                       Never
# 3                       Never
# 4  Once a month or more often
#
#                                           opensource  \
# 0  The quality of OSS and closed source software ...
# 1  The quality of OSS and closed source software ...
# 2  The quality of OSS and closed source software ...
# 3  The quality of OSS and closed source software ...
# 4  OSS is, on average, of HIGHER quality than pro...
#
# ...

# %%
df.columns = df.columns.str.replace(' ', '_')

# %%
df.rename(columns={'convertedcomp':'package'}, inplace=True)

# %%
df.columns
# Out:
# Index(['respondent', 'mainbranch', 'hobbyist', 'opensourcer', 'opensource',
#        'employment', 'country', 'student', 'edlevel', 'undergradmajor',
#        'eduother', 'orgsize', 'devtype', 'yearscode', 'age1stcode',
#        'yearscodepro', 'careersat', 'jobsat', 'mgridiot', 'mgrmoney',
#        'mgrwant', 'jobseek', 'lasthiredate', 'lastint', 'fizzbuzz',
#        'jobfactors', 'resumeupdate', 'currencysymbol', 'currencydesc',
#        'comptotal', 'compfreq', 'package', 'workweekhrs', 'workplan',
#        'workchallenge', 'workremote', 'workloc', 'impsyn', 'coderev',
#        'coderevhrs', 'unittests', 'purchasehow', 'purchasewhat',
#        'languageworkedwith', 'languagedesirenextyear', 'databaseworkedwith',
#        'databasedesirenextyear', 'platformworkedwith',
#        'platformdesirenextyear', 'webframeworkedwith',
#        'webframedesirenextyear', 'misctechworkedwith',
#        'misctechdesirenextyear', 'devenviron', 'opsys', 'containers',
# ...

# %%
df.reindex(sorted(df.columns),axis =1)
# Out:
#         age age1stcode betterlife  \
# 0      14.0         10        Yes
# 1      19.0         17        Yes
# 2      28.0         22        Yes
# 3      22.0         16        Yes
# 4      30.0         14        Yes
# ...     ...        ...        ...
# 88878   NaN        NaN        Yes
# 88879   NaN        NaN        NaN
# 88880   NaN        NaN        NaN
# 88881   NaN        NaN        NaN
# 88882  18.0         11        Yes
#
#                                             blockchainis blockchainorg  \
# 0                                                    NaN           NaN
# 1      Useful across many domains and could change ma...           NaN
# 2                                                    NaN           NaN
# 3      Useful for decentralized currency (i.e., Bitcoin)    Not at all
# 4                                                    NaN    Not at all
# ...                                                  ...           ...
# ...

# %%
df.set_index('respondent')
# Out:
#                                                    mainbranch hobbyist  \
# respondent
# 1                      I am a student who is learning to code      Yes
# 2                      I am a student who is learning to code       No
# 3           I am not primarily a developer, but I write co...      Yes
# 4                              I am a developer by profession       No
# 5                              I am a developer by profession      Yes
# ...                                                       ...      ...
# 88377                                                     NaN      Yes
# 88601                                                     NaN       No
# 88802                                                     NaN       No
# 88816                                                     NaN       No
# 88863                                                     NaN      Yes
#
#                                                   opensourcer  \
# respondent
# ...

# %%
df['package']
# Out:
# 0            NaN
# 1            NaN
# 2         8820.0
# 3        61000.0
# 4            NaN
#           ...
# 88878        NaN
# 88879        NaN
# 88880        NaN
# 88881        NaN
# 88882        NaN
# Name: package, Length: 88883, dtype: float64

# %%
df.loc[8,'package'] = [10000] #updating the single row value

# %%
df.loc[8,'package']
# Out:
# 10000.0

# %%
df.columns
# Out:
# Index(['respondent', 'mainbranch', 'hobbyist', 'opensourcer', 'opensource',
#        'employment', 'country', 'student', 'edlevel', 'undergradmajor',
#        'eduother', 'orgsize', 'devtype', 'yearscode', 'age1stcode',
#        'yearscodepro', 'careersat', 'jobsat', 'mgridiot', 'mgrmoney',
#        'mgrwant', 'jobseek', 'lasthiredate', 'lastint', 'fizzbuzz',
#        'jobfactors', 'resumeupdate', 'currencysymbol', 'currencydesc',
#        'comptotal', 'compfreq', 'package', 'workweekhrs', 'workplan',
#        'workchallenge', 'workremote', 'workloc', 'impsyn', 'coderev',
#        'coderevhrs', 'unittests', 'purchasehow', 'purchasewhat',
#        'languageworkedwith', 'languagedesirenextyear', 'databaseworkedwith',
#        'databasedesirenextyear', 'platformworkedwith',
#        'platformdesirenextyear', 'webframeworkedwith',
#        'webframedesirenextyear', 'misctechworkedwith',
#        'misctechdesirenextyear', 'devenviron', 'opsys', 'containers',
# ...

# %%
# changing values of all rows using apply
df['opensourcer'] =df['opensourcer'].apply(lambda x: x.upper())

# %%
def change(string):
    if string=='Yes':
        return 1
    else:
        return 0

# %%
df['hobbyist'].apply(change)
# Out:
# 0        1
# 1        0
# 2        1
# 3        0
# 4        1
#         ..
# 88878    1
# 88879    0
# 88880    0
# 88881    0
# 88882    1
# Name: hobbyist, Length: 88883, dtype: int64

# %%
df['hobbyist'].apply(lambda x: 1 if x == 'Yes' else 0)
# Out:
# 0        1
# 1        0
# 2        1
# 3        0
# 4        1
#         ..
# 88878    1
# 88879    0
# 88880    0
# 88881    0
# 88882    1
# Name: hobbyist, Length: 88883, dtype: int64

# %%
df['hobbyist'].map({'Yes': True,'No': False}) #it will replace all yes and no value and change other value to nan
# Out:
# 0         True
# 1        False
# 2         True
# 3        False
# 4         True
#          ...
# 88878     True
# 88879    False
# 88880    False
# 88881    False
# 88882     True
# Name: hobbyist, Length: 88883, dtype: bool

# %%
df['hobbyist'].replace({'Yes': True,'No': False}) # it will change only mention value(yes and no) and keep other values same
# Out:
# 0         True
# 1        False
# 2         True
# 3        False
# 4         True
#          ...
# 88878     True
# 88879    False
# 88880    False
# 88881    False
# 88882     True
# Name: hobbyist, Length: 88883, dtype: bool

# %%
data = pd.DataFrame({'first': ['rishabh', 'Lakshya', 'Pranjul'],
                    'Last':['Vimal','Jain','Rastogi'],
                    'email':['rishabh@gmail.com','lakshya@gmail.com','pranjul@gmail.com']})

# %%
data.rename(columns={'first': 'firstname'})
data['first'].apply(lambda x: x.upper())
# Out:
# 0    RISHABH
# 1    LAKSHYA
# 2    PRANJUL
# Name: first, dtype: object

# %%
data['age'] = [20,23,22]

# %%
data
# Out:
#      first     Last              email  age
# 0  rishabh    Vimal  rishabh@gmail.com   20
# 1  Lakshya     Jain  lakshya@gmail.com   23
# 2  Pranjul  Rastogi  pranjul@gmail.com   22

# %%
data['age'].astype(float)
# Out:
# 0    20.0
# 1    23.0
# 2    22.0
# Name: age, dtype: float64

# %%
data
# Out:
#      first     Last              email  age
# 0  rishabh    Vimal  rishabh@gmail.com   20
# 1  Lakshya     Jain  lakshya@gmail.com   23
# 2  Pranjul  Rastogi  pranjul@gmail.com   22

# %%
data['name'] = data['first'] +' '+ data['Last']

# %%
data.drop(columns=['first','Last'], inplace=True)

# %%
data
# Out:
#                email  age             name
# 0  rishabh@gmail.com   20    rishabh Vimal
# 1  lakshya@gmail.com   23     Lakshya Jain
# 2  pranjul@gmail.com   22  Pranjul Rastogi

# %%
data[['First','Last']]= data['name'].str.split(' ', expand= True)

# %%
data
# Out:
#                email  age             name    First     Last
# 0  rishabh@gmail.com   20    rishabh Vimal  rishabh    Vimal
# 1  lakshya@gmail.com   23     Lakshya Jain  Lakshya     Jain
# 2  pranjul@gmail.com   22  Pranjul Rastogi  Pranjul  Rastogi

# %%
data.append({'First': 'Sandeep'}, ignore_index=True)
# Out:
#                email   age             name    First     Last
# 0  rishabh@gmail.com  20.0    rishabh Vimal  rishabh    Vimal
# 1  lakshya@gmail.com  23.0     Lakshya Jain  Lakshya     Jain
# 2  pranjul@gmail.com  22.0  Pranjul Rastogi  Pranjul  Rastogi
# 3                NaN   NaN              NaN  Sandeep      NaN

# %%
data2 = pd.DataFrame({'First': ['Suryansh', 'Prakhar'],
                    'Last':['Kaushik','Kumar'],
                    'email':['pingu@gmail.com','pokar@gmail.com']})

# %%
data2
# Out:
#       First     Last            email
# 0  Suryansh  Kaushik  pingu@gmail.com
# 1   Prakhar    Kumar  pokar@gmail.com

# %%
data = data.append(data2, ignore_index=True)

# %%
data
# Out:
#                email   age             name     First     Last
# 0  rishabh@gmail.com  20.0    rishabh Vimal   rishabh    Vimal
# 1  lakshya@gmail.com  23.0     Lakshya Jain   Lakshya     Jain
# 2  pranjul@gmail.com  22.0  Pranjul Rastogi   Pranjul  Rastogi
# 3    pingu@gmail.com   NaN              NaN  Suryansh  Kaushik
# 4    pokar@gmail.com   NaN              NaN   Prakhar    Kumar

# %%
data.drop(index = data[data['age'].isna()].index)
# Out:
#                email   age             name    First     Last
# 0  rishabh@gmail.com  20.0    rishabh Vimal  rishabh    Vimal
# 1  lakshya@gmail.com  23.0     Lakshya Jain  Lakshya     Jain
# 2  pranjul@gmail.com  22.0  Pranjul Rastogi  Pranjul  Rastogi

# %%
data
# Out:
#                email   age             name     First     Last
# 0  rishabh@gmail.com  20.0    rishabh Vimal   rishabh    Vimal
# 1  lakshya@gmail.com  23.0     Lakshya Jain   Lakshya     Jain
# 2  pranjul@gmail.com  22.0  Pranjul Rastogi   Pranjul  Rastogi
# 3    pingu@gmail.com   NaN              NaN  Suryansh  Kaushik
# 4    pokar@gmail.com   NaN              NaN   Prakhar    Kumar

# %%
data.sort_values('age', ascending=False)
# Out:
#                email   age             name     First     Last
# 1  lakshya@gmail.com  23.0     Lakshya Jain   Lakshya     Jain
# 2  pranjul@gmail.com  22.0  Pranjul Rastogi   Pranjul  Rastogi
# 0  rishabh@gmail.com  20.0    rishabh Vimal   rishabh    Vimal
# 3    pingu@gmail.com   NaN              NaN  Suryansh  Kaushik
# 4    pokar@gmail.com   NaN              NaN   Prakhar    Kumar

# %%
df.sort_values(by = ['country','package'],ascending=[True, False], inplace=True)

# %%
df[['country','package']].head(50)
# Out:
#            country    package
# 62723  Afghanistan  1000000.0
# 50172  Afghanistan   153216.0
# 39018  Afghanistan    19152.0
# 58082  Afghanistan    17556.0
# 7056   Afghanistan    14364.0
# 22327  Afghanistan     7980.0
# 48122  Afghanistan     4464.0
# 10697  Afghanistan     3996.0
# 8112   Afghanistan     1596.0
# 29560  Afghanistan     1116.0
# 719    Afghanistan        0.0
# 28470  Afghanistan        0.0
# 6391   Afghanistan        NaN
# 7323   Afghanistan        NaN
# 12253  Afghanistan        NaN
# 26189  Afghanistan        NaN
# 28877  Afghanistan        NaN
# 32971  Afghanistan        NaN
# 37571  Afghanistan        NaN
# 39754  Afghanistan        NaN
# 42832  Afghanistan        NaN
# 44123  Afghanistan        NaN
# 45562  Afghanistan        NaN
# 46807  Afghanistan        NaN
# 49377  Afghanistan        NaN
# 50437  Afghanistan        NaN
# 51525  Afghanistan        NaN
# 58390  Afghanistan        NaN
# 59184  Afghanistan        NaN
# 60185  Afghanistan        NaN
# ...

# %%
df['package'].nlargest(10)
# Out:
# 25833    2000000.0
# 87353    2000000.0
# 21895    2000000.0
# 28080    2000000.0
# 72274    2000000.0
# 77665    2000000.0
# 79701    2000000.0
# 51798    2000000.0
# 75088    2000000.0
# 32056    2000000.0
# Name: package, dtype: float64

# %%
df.nlargest(10,'package')
# Out:
#        respondent                                         mainbranch hobbyist  \
# 25833       25983                     I am a developer by profession      Yes
# 87353       87896                     I am a developer by profession      Yes
# 21895       22013                     I am a developer by profession      Yes
# 28080       28243                     I am a developer by profession      Yes
# 72274       72732  I am not primarily a developer, but I write co...       No
# 77665       78151                     I am a developer by profession      Yes
# 79701       80200                     I am a developer by profession      Yes
# 51798       52132                     I am a developer by profession      Yes
# 75088       75561                     I am a developer by profession      Yes
# 32056       32250                     I am a developer by profession      Yes
#
#                                              opensourcer  \
# ...

# %%
df['socialmedia'].value_counts(normalize = True) # to get each percentage
# Out:
# Reddit                      0.170233
# YouTube                     0.163791
# WhatsApp                    0.158071
# Facebook                    0.156069
# Twitter                     0.134988
# Instagram                   0.074150
# I don't use social media    0.065777
# LinkedIn                    0.053306
# WeChat 微信                   0.007899
# Snapchat                    0.007437
# VK ВКонта́кте               0.007141
# Weibo 新浪微博                  0.000663
# Youku Tudou 优酷              0.000249
# Hello                       0.000225
# Name: socialmedia, dtype: float64

# %%
country_grp = df.groupby(['country'])

# %%
country_grp.get_group('United States')
# Out:
#        respondent                      mainbranch hobbyist  \
# 57             58  I am a developer by profession      Yes
# 101           102  I am a developer by profession       No
# 164           166  I am a developer by profession      Yes
# 434           436  I am a developer by profession      Yes
# 450           452  I am a developer by profession      Yes
# ...           ...                             ...      ...
# 88818       78292                             NaN       No
# 88840       82717                             NaN       No
# 88844       83397                             NaN      Yes
# 88859       85642                             NaN       No
# 88877       88282                             NaN      Yes
#
#                       opensourcer  \
# 57     ONCE A MONTH OR MORE OFTEN
# 101                         NEVER
# 164       LESS THAN ONCE PER YEAR
# 434       LESS THAN ONCE PER YEAR
# 450                         NEVER
# ...                           ...
# ...

# %%
personwhoknowpython =country_grp['languageworkedwith'].apply(lambda x: x.str.contains('Python').sum())

# %%
totalperson = df['country'].value_counts()

# %%
totalperson
# Out:
# United States            20949
# India                     9061
# Germany                   5866
# United Kingdom            5737
# Canada                    3395
#                          ...
# Saint Kitts and Nevis        1
# Papua New Guinea             1
# Sao Tome and Principe        1
# Brunei Darussalam            1
# Tonga                        1
# Name: country, Length: 179, dtype: int64

# %%
new_df = pd.concat([personwhoknowpython,totalperson],axis = 'columns',sort= False)

# %%
new_df.sort_values(by = 'country', ascending=False, inplace=True)

# %%
new_df['pythonpercentage']  = (new_df['languageworkedwith']/new_df['country'])*100
new_df
# Out:
#                                   languageworkedwith  country  \
# United States                                  10083    20949
# India                                           3105     9061
# Germany                                         2451     5866
# United Kingdom                                  2384     5737
# Canada                                          1558     3395
# ...                                              ...      ...
# North Korea                                        0        1
# Niger                                              1        1
# Saint Vincent and the Grenadines                   0        1
# Chad                                               0        1
# Brunei Darussalam                                  0        1
#
#                                   pythonpercentage
# United States                            48.131176
# India                                    34.267741
# Germany                                  41.783157
# ...
